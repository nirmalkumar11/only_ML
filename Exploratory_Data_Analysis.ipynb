# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# numpy for numerical operation
#
# pandas for handle dataframe
#
# matplotlib and seaborn for data visualisation
#
# bit.ly/aimldst
#
# bit.ly/T_AIML

# %% [markdown]
# #EDA - basic understanding of data
#
# head, tail, shape, info, describe,

# %%
df=pd.read_csv('/content/drive/MyDrive/MLT/Copy of diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# count - find missing value. if 766 there is 2 missing value
#
# mean - find outlier, error values. if avg of mark feature is 300, that featur contain outlier
#
# std - deviation of data from mean
#
# min, max - give min and max value
#
# % - quantails

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# use maximum 16 features, if it contains more the accurasy is dip

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# isnull() - find null vlues
#
# .sum() - add the count

# %% [markdown]
# #Line Graph

# %%
plt.figure(figsize=(50, 20))
plt.plot(df['BloodPressure'])

# %% [markdown]
# it is use to know about data pattern and understand trend.
#
# one feature is enough.
#
# used in stocks and price prediction

# %% [markdown]
# #Scatter plot

# %%
plt.scatter(df['Pregnancies'], df['BMI'])

# %% [markdown]
# to know about corelation(association between two features) between two features.
#
# used to find outliers

# %%
plt.bar(df['Pregnancies'], df['BMI'])
# Out:
# <BarContainer object of 768 artists>

# %% [markdown]
# use two features
#
# comparing quantities across different groups

# %%
plt.hist( df['BMI'])
# Out:
# (array([ 11.,   0.,  15., 156., 268., 224.,  78.,  12.,   3.,   1.]),
#  array([ 0.  ,  6.71, 13.42, 20.13, 26.84, 33.55, 40.26, 46.97, 53.68,
#         60.39, 67.1 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# use single feature
#
# to know about data distribution and frequensy.
#
# the datadistribution must be normal.
#
# to know the targated people in the distribution.

# %%
col=df.columns.tolist()
for i in range(len(col)):
  plt.subplot(3,3,i+1)
  plt.hist(df[col[i]])

# %%
cols=df.columns.tolist()

# %%
for i in range(len(df.columns.tolist())):
  plt.subplot(3,3,i+1)
  plt.plot(df[cols[i]])

# %%
plt.pie(df['Outcome'])
plt.show()

# %% [markdown]
# all values in the outcomes is floared(roundof vaues) value
#
# single feature is enough

# %% [markdown]
# #Seaborn
#
# line graph - line plot
#
# scatter grapg - scatterplot
#
# bar graph - barplot
#
# histogram - displot, dist plot

# %%
sns.lineplot(df['BMI'])
# Out:
# <Axes: ylabel='BMI'>

# %%
sns.scatterplot(x=df['BMI'], y=df['Pregnancies'], data=df)
# Out:
# <Axes: xlabel='BMI', ylabel='Pregnancies'>

# %% [markdown]
# normal method is throw error, use the following fragment
#
# sns.scatterplot(x=, y=, data=)

# %%
sns.barplot(x=df['BMI'], y=df['Pregnancies'], data=df)
# Out:
# <Axes: xlabel='BMI', ylabel='Pregnancies'>

# %%
sns.displot(x=df['BMI'], y=df['Pregnancies'], data=df)

# %%
sns.distplot(x=df['BMI'])
# Out:
# /tmp/ipykernel_8162/3102881176.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['BMI'])
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df, hue='Outcome')
