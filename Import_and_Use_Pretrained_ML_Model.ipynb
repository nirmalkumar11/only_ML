# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import load_model

# %%
model=load_model('/content/mnistmodel1.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2

# %%
img=cv2.imread('/content/Screenshot 2026-06-04 at 10.09.11.png',0)
# /content/Screenshot 2026-06-04 at 10.09.11.png

# %%
img_resized = cv2.resize(img, (28, 28), interpolation=cv2.INTER_AREA)

img_normalized = img_resized / 255.0

img_input = img_normalized.reshape(1, 28, 28, 1)

print(f"Original image shape: {img.shape}")
print(f"Resized image shape: {img_resized.shape}")
print(f"Final input shape for model: {img_input.shape}")
# Out:
# Original image shape: (598, 356)
# Resized image shape: (28, 28)
# Final input shape for model: (1, 28, 28, 1)

# %% [markdown]
# Now that the image is prepared, you can use it as input to your `model` to make a prediction.

# %%
import numpy as np
prediction = model.predict(img_input)
display(np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# np.int64(9)

# %%
data=keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = data.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train[10].shape
# Out:
# (28, 28)

# %%
model=keras.Sequential()

# %%
x_train, x_test = x_train/255.0, x_test/255.0

# %%
x_train=x_train.reshape(-1, 28,28,1)
x_test=x_test.reshape(-1, 28,28,1)

# %%
from tensorflow.keras import layers

# %%
model=keras.models.Sequential()

# %%
model.add(keras.layers.Conv2D(32, (2,2), activation='relu', input_shape=(28, 28, 1)))
model.add(keras.layers.MaxPooling2D((2,2)))
model.add(keras.layers.Conv2D(32, (2,2), activation='relu', input_shape=(28, 28, 1)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, validation_split=0.1, epochs=5)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 47s 27ms/step - accuracy: 0.9521 - loss: 0.1590 - val_accuracy: 0.9863 - val_loss: 0.0571
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 44s 26ms/step - accuracy: 0.9841 - loss: 0.0514 - val_accuracy: 0.9860 - val_loss: 0.0550
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 81s 26ms/step - accuracy: 0.9907 - loss: 0.0310 - val_accuracy: 0.9887 - val_loss: 0.0453
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 82s 26ms/step - accuracy: 0.9927 - loss: 0.0223 - val_accuracy: 0.9877 - val_loss: 0.0489
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 43s 26ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.9890 - val_loss: 0.0435

# %%
np.argmax(model.predict(img_input))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# np.int64(2)
