# %%
import pandas as pd
import numpy as np

# %%
insurance=pd.read_csv('/content/drive/MyDrive/MLT/Copy of insurance_claims.csv')

# %%
insurance.shape
# Out:
# (1000, 40)

# %%
insurance.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
insurance.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
insurance.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
insurance.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
insurance['authorities_contacted'].fillna(insurance['authorities_contacted'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_851/3585942246.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   insurance['authorities_contacted'].fillna(insurance['authorities_contacted'].mode()[0], inplace=True)

# %%
insurance['authorities_contacted'].isnull().sum()
# Out:
# np.int64(0)

# %%
insurance.drop(['_c39'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cols=insurance.columns.tolist()

for i in cols:
  insurance[i]=le.fit_transform(insurance[i])

# %%
print(len(cols))
# Out:
# 39

# %%
insurance.head()
# Out:
#    months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                 299   29            480               940             2
# 1                 212   23            257               635             1
# 2                 123   10            672               413             2
# 3                 239   22            140                19             0
# 4                 212   25            286               922             0
#
#    policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0           1                  1                    732               1
# 1           1                  2                    396               5
# 2           0                  2                    740               5
# 3           1                  2                    743               6
# 4           2                  1                    902               6
#
#    insured_zip  ...  witnesses  police_report_available  total_claim_amount  \
# ...

# %%
find_outlier(insurance)

# %%
# def clear_outlier(df):
#   import math
#   import numpy as np
#   import seaborn as sns

#   cols=df.columns.tolist()
#   x=int(np.ceil(np.sqrt(len(cols[:-1]))))
#   fig,ax = plt.subplots(x,x, figsize=(x*5, x*5))

for i in ['age', 'umbrella_limit']:
  q1=insurance[i].quantile(0.25)
  q2=insurance[i].quantile(0.75)

  iqr=q2-q1
  print(i)
  outlier=insurance[(insurance[i]<q1-iqr*1.5) | (insurance[i]>q2+iqr*1.5)]
  print((outlier))
  print()
  print()

    # if outlier.empty:
    #     !pip install scipy
    #     from scipy.stats.mstats import winsorize

    #     winsorized=winsorize(df[i], (0.1, 0.1))
# Out:
# age
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 67                  389   45            262                29             2
# 538                 389   44            839               749             0
# 588                 385   45            895               855             1
# 947                 382   44            497               839             0
#
#      policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 67            1                  0                     41               1
# 538           1                  1                    550               1
# 588           1                  0                    140               1
# 947           1                  0                    160               6
#
#      insured_zip  ...  witnesses  police_report_available  total_claim_amount  \
# 67           736  ...          1                        1                 139
# ...

# %%
insurance.drop('umbrella_limit', axis=1,inplace=True)

# %%
insurance.drop([67, 538, 588, 947],inplace=True)

# %%
insurance.shape
# Out:
# (996, 38)

# %%
# from scipy.stats.mstats import winsorize
# for i in ['age', 'umbrella_limit']:

#     winsorized=winsorize(insurance[i], (0.1, 0.1))
#     print(len(winsorized))

#     q1=pd.DataFrame(winsorized, columns=i).quantile(0.25)
#     q2=winsorized.quantile(0.75)

#     iqr=q2-q1
#     print(i)
#     outlier=winsorized[(winsorized<q1-iqr*1.5) | (winsorized>q2+iqr*1.5)]
#     print((outlier))
#     print()
#     print()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
cols=insurance.columns.tolist()
for i in cols[:-1]:
  insurance[i]=sc.fit_transform(insurance[[i]])

# %%
insurance.head()
# Out:
#    months_as_customer       age  policy_number  policy_bind_date  \
# 0            1.164367  1.014451      -0.065826          1.717131
# 1            0.287525  0.349281      -0.838298          0.603034
# 2           -0.609475 -1.091921       0.599261         -0.207882
# 3            0.559648  0.238419      -1.243586         -1.647075
# 4            0.287525  0.571005      -0.737842          1.651381
#
#    policy_state  policy_csl  policy_deductable  policy_annual_premium  \
# 0      1.186130    0.061059           0.039925               0.823661
# 1     -0.018137    0.061059           1.282605              -0.353154
# 2      1.186130   -1.180065           1.282605               0.851681
# 3     -1.222403    0.061059           1.282605               0.862188
# 4     -1.222403    1.302184           0.039925               1.419074
#
#    insured_zip  insured_sex  ...  witnesses  police_report_available  \
# 0    -0.033306     1.077275  ...   0.465915                 1.267591
# ...

# %%
x=insurance.drop('fraud_reported', axis=1)

# %%
y=insurance['fraud_reported']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc=DecisionTreeClassifier(max_depth=10, criterion='entropy')

# %%
model_dc=dc.fit(x_train, y_train)

# %%
y_pred=model_dc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

print('accuracy_score')
print(accuracy_score(y_test, y_pred))
print()
'printconfusion_matrix'
print(confusion_matrix(y_test, y_pred))
print()
print('classification_report')
print(classification_report(y_test, y_pred))
# Out:
# accuracy_score
# 0.7911646586345381
#
# [[166  28]
#  [ 24  31]]
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86       194
#            1       0.53      0.56      0.54        55
#
#     accuracy                           0.79       249
#    macro avg       0.70      0.71      0.70       249
# weighted avg       0.80      0.79      0.79       249

# %%
import matplotlib.pyplot as plt
from sklearn import tree
tree.plot_tree(model_dc, filled=True, fontsize=5, max_depth=5)
plt.show(
)
