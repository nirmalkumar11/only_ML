# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/AI Training/Datasets/Copy of Market_Basket_Optimisation.csv', header=None)

# %%
df.shape
# Out:
# (7501, 20)

# %%
df.isnull().sum()
# Out:
# 0        0
# 1     1754
# 2     3112
# 3     4156
# 4     4972
# 5     5637
# 6     6132
# 7     6520
# 8     6847
# 9     7106
# 10    7245
# 11    7347
# 12    7414
# 13    7454
# 14    7476
# 15    7493
# 16    7497
# 17    7497
# 18    7498
# 19    7500
# dtype: int64

# %%
df.shape
# Out:
# (7501, 20)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df.iloc[1]
# Out:
# 0       burgers
# 1     meatballs
# 2          eggs
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# Name: 1, dtype: object

# %%
df.iloc[2].isnull().sum()
# Out:
# np.int64(19)

# %%
transaction=[]

for i in range(len(df)):
  transaction.append([i for i in df.iloc[i] if not pd.isna(i)])

# %%
print(transaction[1])
# Out:
# ['burgers', 'meatballs', 'eggs']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 1.1+ MB

# %%
print(type(transaction[2][0]))
# Out:
# <class 'str'>

# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=3eac5db06a8917639ddaaf06a1c354236d8ae0370fbf6b5dc61e2be2a7616ccc
#   Stored in directory: /root/.cache/pip/wheels/7f/49/e3/42c73b19a264de37129fadaa0c52f26cf50e87de08fb9804af
# Successfully built apyori
# ...

# %%
len(transaction)
# Out:
# 7501

# %%
from apyori import apriori

# %%
rules=apriori(transactions=transaction, min_support=0.001, min_confidence=0.1, min_lift=2, min_length=2, max_length=2)
results=list(rules)

# %%
len(results)
# Out:
# 285

# %%
rules
# Out:
# <generator object apriori at 0x7db8fe831a80>

# %%
# print(results[0])
for i in results[0]:
  print(i)
# Out:
# frozenset({'burgers', 'almonds'})
# 0.005199306759098787
# [OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]

# %%
li=((list(results[0])))

# %%
for i in range(len((list(results[0])))):
  print(li[i])
# Out:
# frozenset({'burgers', 'almonds'})
# 0.005199306759098787
# [OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]

# %%
li2=((list(results[1])))

# %%
print(list(results[1]))
# Out:
# [frozenset({'frozen smoothie', 'almonds'}), 0.0027996267164378083, [OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'frozen smoothie'}), confidence=0.13725490196078433, lift=2.1674716202270385)]]

# %%
for i in range(len((list(results[1])[2]))):
  print(li2[2][i])
# Out:
# OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'frozen smoothie'}), confidence=0.13725490196078433, lift=2.1674716202270385)

# %%
li=[]
for i in results:
  # for j in range(len(list(i))):
    df={}
    df['lhs']=list(i[2][0][0])[0]
    df['rhs']=list(i[2][0][1])[0]
    df['support']=i[1]
    df['confidence']=i[2][0][2]
    df['lift']=i[2][0][3]
    # print(i[j])

# %%
print(len(results))
# Out:
# 285

# %%
li=[]
for i in results:
  # for j in range(len(list(i))):
    xdf={}
    xdf['lhs']=list(i[2][0][0])[0]
    xdf['rhs']=list(i[2][0][1])[0]
    xdf['support']=i[1]
    xdf['confidence']=i[2][0][2]
    xdf['lift']=i[2][0][3]
    li.append(xdf)
    # print(i[j])

# %%
pd.DataFrame(li)
# Out:
#                    lhs                rhs   support  confidence      lift
# 0              almonds            burgers  0.005199    0.254902  2.923577
# 1              almonds    frozen smoothie  0.002800    0.137255  2.167472
# 2              almonds          olive oil  0.002933    0.143791  2.183351
# 3              almonds               soup  0.002266    0.111111  2.199062
# 4    antioxydant juice            cereals  0.001466    0.164179  6.380868
# ..                 ...                ...       ...         ...       ...
# 280      strong cheese          spaghetti  0.003733    0.482759  2.772720
# 281                tea          spaghetti  0.001466    0.379310  2.178566
# 282       tomato sauce          spaghetti  0.006266    0.443396  2.546642
# 283   whole weat flour           tomatoes  0.001333    0.142857  2.088833
# 284               yams  whole wheat pasta  0.001200    0.104651  3.551984
#
# [285 rows x 5 columns]

# %%
for i in (results[0]):
  print(i)
# Out:
# frozenset({'burgers', 'almonds'})
# 0.005199306759098787
# [OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]

# %%
for i in results:
  print(list(i[2][0][0])[0])
  print(list(i[2][0][1])[0])
  print(i[1])
  print(i[2][0][2])
  print(i[2][0][3])
# Out:
# almonds
# burgers
# 0.005199306759098787
# 0.25490196078431376
# 2.923577382023146
# almonds
# frozen smoothie
# 0.0027996267164378083
# 0.13725490196078433
# 2.1674716202270385
# almonds
# olive oil
# 0.0029329422743634183
# 0.14379084967320263
# 2.1833505331957346
# almonds
# soup
# 0.0022663644847353685
# 0.1111111111111111
# 2.1990618586924655
# antioxydant juice
# cereals
# 0.0014664711371817091
# 0.16417910447761194
# 6.38086768231382
# antioxydant juice
# frozen smoothie
# 0.0011998400213304892
# 0.1343283582089552
# 2.121256873527101
# asparagus
# milk
# 0.0013331555792560992
# 0.2857142857142857
# 2.2048794826572604
# avocado
# frozen smoothie
# 0.005065991201173177
# 0.152
# 2.4003200000000002
# melons
# avocado
# 0.0013331555792560992
# 0.11111111111111112
# 3.3337777777777777
# avocado
# soup
# 0.004399413411545127
# 0.132
# 2.6124854881266493
# toothpaste
# avocado
# 0.0010665244634048793
# 0.13114754098360656
# 3.9349508196721312
# yams
# avocado
# ...

# %%
for i in results:
  print(((i[2][0][2])))
# Out:
# 0.25490196078431376
# 0.13725490196078433
# 0.14379084967320263
# 0.1111111111111111
# 0.16417910447761194
# 0.1343283582089552
# 0.2857142857142857
# 0.152
# 0.11111111111111112
# 0.132
# 0.13114754098360656
# 0.10465116279069768
# 0.3823529411764706
# 0.13846153846153847
# 0.2307692307692308
# 0.13846153846153847
# 0.18461538461538463
# 0.24615384615384614
# 0.12307692307692307
# 0.13846153846153847
# 0.24615384615384614
# 0.12307692307692307
# 0.36923076923076925
# 0.13846153846153847
# 0.15384615384615385
# 0.1851851851851852
# 0.1111111111111111
# 0.1111111111111111
# 0.19753086419753085
# 0.12345679012345678
# 0.2345679012345679
# 0.12149532710280372
# 0.14018691588785048
# 0.29906542056074764
# 0.14018691588785048
# 0.13043478260869565
# 0.13043478260869565
# 0.18840579710144928
# 0.15942028985507248
# 0.2608695652173913
# 0.11594202898550723
# 0.15942028985507248
# 0.14492753623188406
# 0.37681159420289856
# 0.37209302325581395
# 0.16279069767441862
# 0.10276679841897232
# ...

# %%
for i in (list(i[2][0])):
  print(i)
# Out:
# frozenset({'yams'})
# frozenset({'whole wheat pasta'})
# 0.10465116279069768
# 3.551983584131327
